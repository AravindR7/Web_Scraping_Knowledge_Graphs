# %% [markdown]
# https://docs.google.com/document/d/1-88e_XNNtWTNs8dCpjhM4-XGqfvU5GEu2YWHwo5hCR4/edit#heading=h.fgdpsk66a3kh

# %%
# !pip install neptune-notebooks

# %%
# !pip install psutil

# %%
# !jupyter nbextension enable --py neptune-notebooks

# %% [markdown]
# ## Ensemble of Web Scraping, Computational Linguists, NLP algorithms and Graph Theory

# %% [markdown]
# **Knowledge graphs** are tools of data science that deals with interconnected entities(people, organization, places, events etc). Entities are the nodes which are connnectes via edges. Knowledge graph consist of these entity pairs that can be traversed to uncover meaningful connections in unstructured data.

# %%
# !pip install wikipedia-api pandas spacy networkx scipy

# %%
# !pip install scipy
# Out:
# Collecting scipy
#   Downloading scipy-1.7.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (28.4 MB)
#      |████████████████████████████████| 28.4 MB 597 kB/s eta 0:00:01
# Requirement already satisfied: numpy<1.23.0,>=1.16.5 in /home/laptop-pr-13/Documents/Data Science/NLP/env/lib/python3.8/site-packages (from scipy) (1.19.5)
# Installing collected packages: scipy
# Successfully installed scipy-1.7.0
# WARNING: You are using pip version 20.1.1; however, version 21.1.3 is available.
# You should consider upgrading via the '/home/laptop-pr-13/Documents/Data Science/NLP/env/bin/python3 -m pip install --upgrade pip' command.

# %%
# !python -m spacy download en

# %% [markdown]
# ## Web Scraping
#
# - The following function searches Wikipedia for a given topic and extracts information from the target page and its internal link.

# %%
import pandas as pds
import wikipediaapi
from tqdm import tqdm
import concurrent.futures

# %%
def scrape_wikipedia(name_topic, verbose=True):
    def link_to_wikipedia(link):
        try:
            page = api_wikipedia.page(link)
            if page.exists():
                return {'page': link, 'text': page.text, 'link': page.fullurl, 'categorues': list(page.categories.keys())}
        except:
            return None
        
    api_wikipedia = wikipediaapi.Wikipedia(language='en', extract_format=wikipediaapi.ExtractFormat.WIKI)
    name_of_page = api_wikipedia.page(name_topic)
    if not name_of_page.exists():
        print('Page {} is not present'.format(name_of_page))
        return
    
    links_to_page = list(name_of_page.links.keys())
    procceed = tqdm(desc='Scraped links', unit='', total=len(links_to_page)) if verbose else None
    origin = [{'page': name_topic, 'text': name_of_page.text, 'link': name_of_page.fullurl, 'categories': list(name_of_page.categories.keys())}]
    
    with concurrent.futures.ThreadPoolExecutor(max_workers=5) as executor:
        links_future = {executor.submit(link_to_wikipedia, link): link for link in links_to_page}
        for future in concurrent.futures.as_completed(links_future):
            info = future.result()
            origin.append(info) if info else None
            procceed.update(1) if verbose else None
    procceed.close() if verbose else None
    
    namespaces = ('Wikipedia', 'Special', 'Talk', 'LyricWiki', 'File', 'MediaWiki',
                  'Template', 'Help', 'User', 'Category talk', 'Portal talk')
    origin = pds.DataFrame(origin)
    origin = origin[(len(origin['text']) > 20) & ~(origin['page'].str.startswith(namespaces, na=True))]
    origin['categories'] = origin.categories.apply(lambda a: [b[9:] for b in a])

    origin['topic'] = name_topic
    print('Scraped pages', len(origin))
    
    return origin

# %%
data_wikipedia = scrape_wikipedia('COVID 19')

# %%
data_wikipedia.head()

# %%
data_wikipediakipedia.to_csv('scraped_data.csv')

# %%
import spacy
import pandas as pd
import requests
from spacy import displacy
# import en_core_web_sm

nlp = spacy.load('en_core_web_lg')

from spacy.tokens import Span
from spacy.matcher import Matcher

import matplotlib.pyplot as plot
from tqdm import tqdm
import networkx as ntx
import neptune.new as neptune

# %matplotlib inline

# %%
run = neptune.init(api_token="your API key",
                   project="aravindcr/KnowledgeGraphs")
# Out:
# https://app.neptune.ai/aravindcr/KnowledgeGraphs/e/KNOW-9

# %%
data = pd.read_csv('scraped_data.csv')
data.head()
# Out:
#    Unnamed: 0                                               page  \
# 0           0                                           COVID 19
# 1           1             2020 Russia–Saudi Arabia oil price war
# 2           2  2020 Tablighi Jamaat COVID-19 hotspot in Malaysia
# 3           3       2020 UK GCSE and A-Level grading controversy
# 4           4                            2020 stock market crash
#
#                                                 text  \
# 0  Coronavirus disease 2019 (COVID-19) is a conta...
# 1  On 8 March 2020, Saudi Arabia initiated a pric...
# 2  A Tablighi Jamaat religious conference that to...
# 3  Due to the COVID-19 pandemic in the United Kin...
# 4  The 2020 stock market crash was a major and su...
#
#                                                 link  \
# 0             https://en.wikipedia.org/wiki/COVID-19
# 1  https://en.wikipedia.org/wiki/2020_Russia%E2%8...
# 2  https://en.wikipedia.org/wiki/2020_Tablighi_Ja...
# 3  https://en.wikipedia.org/wiki/2020_UK_GCSE_and...
# 4  https://en.wikipedia.org/wiki/2020_stock_marke...
#
#                                           categories     topic
# 0  ['All Wikipedia articles in need of updating',...  COVID 19
# 1  ['2020 in Russia', '2020 in Saudi Arabia', '20...  COVID 19
# 2  ['2020s in Malaysia', 'COVID-19 pandemic in Ma...  COVID 19
# 3  ['2020 controversies', '2020 in the United Kin...  COVID 19
# 4  ['2020 in economics', 'All articles with dead ...  COVID 19

# %%
data['text'][10]
# Out:
# 'The AbC-19 rapid antibody test is an immunological test for COVID-19 exposure developed by the UK Rapid Test Consortium and manufactured by Abingdon Health. It uses a lateral flow test to determine whether a person has IgG antibodies to the SARS-CoV-2 virus that causes COVID-19. The test uses a single drop of blood obtained from a finger prick and yields results in 20 minutes.\n\nSee also\nCOVID-19 rapid antigen test\n\nReferences\nExternal links\nOfficial website\nAbC 19 Rapid Test Instructions'

# %% [markdown]
# ## Segmenting Sentences

# %%
# Lets take part of the above extracted article
docu = nlp('''The AbC-19 rapid antibody test is an immunological test for COVID-19 exposure developed by 
the UK Rapid Test Consortium and manufactured by Abingdon Health. It uses a lateral flow test to determine 
whether a person has IgG antibodies to the SARS-CoV-2 virus that causes COVID-19. The test uses a single 
drop of blood obtained from a finger prick and yields results in 20 minutes.\n\nSee also\nCOVID-19 rapid 
antigen test''')

for tokn in docu:
    print(tokn.text, "---", tokn.dep_)
# Out:
# The --- det
# AbC-19 --- amod
# rapid --- amod
# antibody --- compound
# test --- nsubj
# is --- ROOT
# an --- det
# immunological --- amod
# test --- attr
# for --- prep
# COVID-19 --- amod
# exposure --- pobj
# developed --- acl
# by --- agent
#
#  ---
# the --- det
# UK --- compound
# Rapid --- compound
# Test --- compound
# Consortium --- pobj
# and --- cc
# manufactured --- conj
# by --- agent
# Abingdon --- compound
# Health --- pobj
# . --- punct
# It --- nsubj
# uses --- ROOT
# a --- det
# lateral --- amod
# flow --- compound
# test --- dobj
# to --- aux
# determine --- xcomp
#
#  ---
# whether --- mark
# a --- det
# person --- nsubj
# has --- ccomp
# IgG --- compound
# antibodies --- dobj
# to --- prep
# the --- det
# SARS --- compound
# - --- punct
# CoV-2 --- compound
# virus --- pobj
# that --- nsubj
# causes --- relcl
# COVID-19 --- dobj
# . --- punct
# The --- det
# test --- nsubj
# uses --- ROOT
# a --- det
# single --- amod
#
#  ---
# drop --- dobj
# of --- prep
# blood --- pobj
# obtained --- acl
# from --- prep
# a --- det
# finger --- compound
# prick --- pobj
# and --- cc
# yields --- conj
# results --- appos
# in --- prep
# 20 --- nummod
# minutes --- pobj
# . --- punct
#
#
#  ---
# See --- ROOT
# also --- advmod
#
#  ---
# COVID-19 --- nmod
# rapid --- amod
#
#  ---
# antigen --- compound
# test --- dep

# %% [markdown]
# ## Extracting entities

# %%
def extract_entities(sents):
    # chunk one
    enti_one = ""
    enti_two = ""
    
    dep_prev_token = "" # dependency tag of previous token in sentence
    
    txt_prev_token = "" # previous token in sentence
    
    prefix = ""
    modifier = ""
    
    
    
    for tokn in nlp(sents):
        # chunk two
        ## move to next token if token is punctuation
        
        if tokn.dep_ != "punct":
            #  check if token is compound word or not
            if tokn.dep_ == "compound":
                prefix = tokn.text
                # add current word to it if prevoius word is 'compound
                if dep_prev_token == "compound":
                    prefix = txt_prev_token + " "+ tokn.text
                    
            # verify if token is modifier or not
            if tokn.dep_.endswith("mod") == True:
                modifier = tokn.text
                # add it to the current word if previous word is 'compound'
                if dep_prev_token == "compound":
                    modifier = txt_prev_token + " "+ tokn.text
                    
            # chunk3
            if tokn.dep_.find("subj") == True:
                enti_one = modifier +" "+ prefix + " "+ tokn.text
                prefix = ""
                modifier = ""
                dep_prev_token = ""
                txt_prev_token = ""
                
            # chunk4 
            if tokn.dep_.find("obj") == True:
                enti_two = modifier +" "+ prefix +" "+ tokn.text
                
            # chunk 5
            # update variable
            dep_prev_token = tokn.dep_
            txt_prev_token = tokn.text
            
    return [enti_one.strip(), enti_two.strip()]

# %%
extract_entities("The AbC-19 rapid antibody test is an immunological test for COVID-19 exposure developed by the UK Rapid Test")
# Out:
# ['rapid antibody test', 'COVID-19 UK Rapid Test']

# %%
pairs_of_entities = []

for i in tqdm(data['text'][:800]):
    pairs_of_entities.append(extract_entities(i))
# Out:
# 100%|██████████| 800/800 [06:20<00:00,  2.10it/s]

# %%
pairs_of_entities[36:42]
# Out:
# [['where aluminium powder', 'such explosives manufacturing'],
#  ['310  people', 'Anal Cancer Research UK'],
#  ['converting UCSC Genome enzyme', '2 PDBe KB'],
#  ['which', '1 US National Medicine'],
#  ['converting UCSC Genome enzyme', '2 PDBe KB'],
#  ['users', 'permanently  taste']]

# %% [markdown]
# ## Relation extraction

# %%
def obtain_relation(sent):
    
    doc = nlp(sent)
    
    matcher = Matcher(nlp.vocab)
    
    pattern = [{'DEP':'ROOT'}, 
            {'DEP':'prep','OP':"?"},
            {'DEP':'agent','OP':"?"},  
            {'POS':'ADJ','OP':"?"}]
    
    matcher.add("matching_1", None, pattern)
    
    matcher = matcher(doc)
    h = len(matcher) - 1
    
    span = doc[matcher[h][1]:matcher[h][2]]
    
    return (span.text)

# %%
# obtain_relation("The AbC-19 rapid antibody test is an immunological test for COVID-19 exposure developed by the UK Rapid Test")

# %%
relations = [obtain_relation(j) for j in tqdm(data['text'][:800])]
# Out:
# 100%|██████████| 800/800 [06:18<00:00,  2.11it/s]

# %%
pd.Series(relations).value_counts()[:50]
# Out:
# References             308
# links                   50
# Factors                 37
# information from        19
# website                 17
# Retrieved               11
# Media                   11
# Information from         8
# Archived                 8
# WHO                      8
# Map                      6
# site                     6
# Headings                 6
# Library of               5
# Cases                    5
# reading                  5
# summary                  5
# Coronavirus              5
# Notes                    4
# statistics for           4
# COVID-19                 4
# website of               3
# Asked                    3
# PMID                     3
# Agency                   3
# ISSN                     3
# Times                    3
# related to COVID-19      3
# Dashboard                3
# Institute                2
# Statistics on            2
# Appearances on           2
# Department of            2
# CoronaTracker            2
# Consulytic               2
# Caribbean                2
# Express                  2
# text of                  2
# Available in             2
# Antibody from            2
# vaccination in           2
# map                      2
# retrieved                2
# May                      2
# Ministry of              2
# protects                 2
# news                     2
# Archived from            2
# page                     2
# enzyme                   2
# dtype: int64

# %% [markdown]
# ## Building graph

# %%
# subject extraction
source = [j[0] for j in pairs_of_entities]

#object extraction
target = [k[1] for k in pairs_of_entities]

data_kgf = pd.DataFrame({'source':source, 'target':target, 'edge':relations})

# %%
# Create DG from the dataframe
graph = ntx.from_pandas_edgelist(data_kgf, "source", "target", 
                          edge_attr=True, create_using=ntx.MultiDiGraph())

# %%
plot.figure(figsize=(14, 14))

posn = ntx.spring_layout(graph)
ntx.draw(graph, with_labels=True, node_color='green', edge_cmap=plot.cm.Blues, pos = posn)
plot.show()
# Out:
# /home/laptop-pr-13/Documents/Data Science/NLP/env/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 38450 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/laptop-pr-13/Documents/Data Science/NLP/env/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 30123 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/laptop-pr-13/Documents/Data Science/NLP/env/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 38364 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/laptop-pr-13/Documents/Data Science/NLP/env/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 37749 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/laptop-pr-13/Documents/Data Science/NLP/env/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 27770 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/laptop-pr-13/Documents/Data Science/NLP/env/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 31574 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/laptop-pr-13/Documents/Data Science/NLP/env/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 32178 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/laptop-pr-13/Documents/Data Science/NLP/env/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 38450 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/laptop-pr-13/Documents/Data Science/NLP/env/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 30123 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/laptop-pr-13/Documents/Data Science/NLP/env/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 38364 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/laptop-pr-13/Documents/Data Science/NLP/env/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 37749 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/laptop-pr-13/Documents/Data Science/NLP/env/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 27770 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/laptop-pr-13/Documents/Data Science/NLP/env/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 31574 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/laptop-pr-13/Documents/Data Science/NLP/env/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 32178 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ### Refine your graph based on certain relations

# %%
graph = ntx.from_pandas_edgelist(data_kgf[data_kgf['edge']=="Information from"], "source", "target", 
                          edge_attr=True, create_using=ntx.MultiDiGraph())

plot.figure(figsize=(14,14))
pos = ntx.spring_layout(graph, k = 0.5) # k regulates the distance between nodes
ntx.draw(graph, with_labels=True, node_color='green', node_size=1400, edge_cmap=plot.cm.Blues, pos = posn)
plot.show()

# %%
graph = ntx.from_pandas_edgelist(data_kgf[data_kgf['edge']=="links"], "source", "target", 
                          edge_attr=True, create_using=ntx.MultiDiGraph())

plot.figure(figsize=(14,14))
pos = ntx.spring_layout(graph, k = 0.5) # k regulates the distance between nodes
ntx.draw(graph, with_labels=True, node_color='green', node_size=1400, edge_cmap=plot.cm.Blues, pos = posn)
plot.show()

# %% [markdown]
# ## Neptune

# %%
# log graphs
run['graphs/all_in_graph'].upload('graph.png')

# %%
run['graphs/filtered_relations'].upload('info.png')

# %%
run['graphs/filtered_relations2'].upload('links.png')
